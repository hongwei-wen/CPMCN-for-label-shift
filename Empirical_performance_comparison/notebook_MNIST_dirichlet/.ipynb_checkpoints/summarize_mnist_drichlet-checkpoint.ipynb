# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

# %%
def get_results(logs):
    results = []
    for idx, line in enumerate(logs):
        if "On alpha" in line:
            alpha = float(line.split(" ")[2])
            for jdx in range(6):
                metric = logs[idx + 13 * jdx + 1].split(" ")[1].strip()
                for kdx in range(4):
                    infos = logs[idx + 13 * jdx + 2 + 3 * kdx].strip()
                    method, _, mean, _, std = infos.split(" ")
                    method = method.split(":")[0]
                    if method == "em":
                        method = "3-" + method
                    elif method == "wen13":
                        method = "4-" + method
                    elif method == "bbse-soft":
                        method = "1-" + method
                    elif method == "rlls-soft":
                        method = "2-" + method
                    mean, std = float(mean), float(std)
                    results.append([alpha, metric, method, mean, std])
    results = pd.DataFrame(results)
    results.columns = ["alpha", "measure", "method", "mean", "std"]
    results = results.sort_values(by=["alpha", "measure", "method"])
    results = results.reset_index(drop=True)
    return results

# %%
with open("log_MNIST_exp1225run1.out", "r") as f:
    logs = f.readlines()
results = get_results(logs)
results
# Out:
#      alpha                 measure       method      mean       std
# 0      0.1             acc_adapted  1-bbse-soft  0.975000  0.001470
# 1      0.1             acc_adapted  2-rlls-soft  0.975000  0.001470
# 2      0.1             acc_adapted         3-em  0.975500  0.001499
# 3      0.1             acc_adapted       wen15B  0.975500  0.001499
# 4      0.1                acc_base  1-bbse-soft  0.911500  0.002872
# 5      0.1                acc_base  2-rlls-soft  0.911500  0.002872
# 6      0.1                acc_base         3-em  0.911500  0.002872
# 7      0.1                acc_base       wen15B  0.911500  0.002872
# 8      0.1               delta_acc  1-bbse-soft  0.056250  0.002827
# 9      0.1               delta_acc  2-rlls-soft  0.056250  0.002826
# 10     0.1               delta_acc         3-em  0.057500  0.002887
# 11     0.1               delta_acc       wen15B  0.057500  0.002889
# 12     0.1                   jsdiv  1-bbse-soft  0.071990  0.002440
# 13     0.1                   jsdiv  2-rlls-soft  0.069261  0.002473
# 14     0.1                   jsdiv         3-em  0.024518  0.001696
# 15     0.1                   jsdiv       wen15B  0.024764  0.001682
# 16     0.1         mseweights_even  1-bbse-soft  0.004128  0.000634
# 17     0.1         mseweights_even  2-rlls-soft  0.003985  0.000635
# 18     0.1         mseweights_even         3-em  0.000849  0.000134
# 19     0.1         mseweights_even       wen15B  0.000842  0.000133
# 20     0.1  mseweights_testsetprop  1-bbse-soft  0.008955  0.003989
# 21     0.1  mseweights_testsetprop  2-rlls-soft  0.009331  0.004006
# 22     0.1  mseweights_testsetprop         3-em  0.002140  0.000644
# 23     0.1  mseweights_testsetprop       wen15B  0.002144  0.000638
# 24     0.2             acc_adapted  1-bbse-soft  0.957500  0.001635
# 25     0.2             acc_adapted  2-rlls-soft  0.957500  0.001637
# 26     0.2             acc_adapted         3-em  0.958750  0.001652
# 27     0.2             acc_adapted       wen15B  0.958750  0.001652
# 28     0.2                acc_base  1-bbse-soft  0.909750  0.002405
# 29     0.2                acc_base  2-rlls-soft  0.909750  0.002405
# 30     0.2                acc_base         3-em  0.909750  0.002405
# 31     0.2                acc_base       wen15B  0.909750  0.002405
# 32     0.2               delta_acc  1-bbse-soft  0.040000  0.002069
# 33     0.2               delta_acc  2-rlls-soft  0.040000  0.002069
# 34     0.2               delta_acc         3-em  0.040750  0.002136
# 35     0.2               delta_acc       wen15B  0.040750  0.002136
# 36     0.2                   jsdiv  1-bbse-soft  0.055107  0.002200
# 37     0.2                   jsdiv  2-rlls-soft  0.054059  0.002206
# 38     0.2                   jsdiv         3-em  0.022509  0.001152
# 39     0.2                   jsdiv       wen15B  0.022884  0.001163
# 40     0.2         mseweights_even  1-bbse-soft  0.003542  0.000534
# 41     0.2         mseweights_even  2-rlls-soft  0.003608  0.000536
# 42     0.2         mseweights_even         3-em  0.001030  0.000241
# 43     0.2         mseweights_even       wen15B  0.001028  0.000241
# 44     0.2  mseweights_testsetprop  1-bbse-soft  0.007604  0.003105
# 45     0.2  mseweights_testsetprop  2-rlls-soft  0.007922  0.003110
# 46     0.2  mseweights_testsetprop         3-em  0.002094  0.000974
# 47     0.2  mseweights_testsetprop       wen15B  0.002112  0.000974
# 48     0.5             acc_adapted  1-bbse-soft  0.940250  0.001549
# 49     0.5             acc_adapted  2-rlls-soft  0.940250  0.001548
# 50     0.5             acc_adapted         3-em  0.939750  0.001572
# 51     0.5             acc_adapted       wen15B  0.939750  0.001572
# 52     0.5                acc_base  1-bbse-soft  0.914500  0.001826
# 53     0.5                acc_base  2-rlls-soft  0.914500  0.001826
# 54     0.5                acc_base         3-em  0.914500  0.001826
# 55     0.5                acc_base       wen15B  0.914500  0.001826
# 56     0.5               delta_acc  1-bbse-soft  0.021000  0.001383
# 57     0.5               delta_acc  2-rlls-soft  0.021000  0.001382
# 58     0.5               delta_acc         3-em  0.021500  0.001382
# 59     0.5               delta_acc       wen15B  0.021500  0.001383
# 60     0.5                   jsdiv  1-bbse-soft  0.034045  0.001617
# 61     0.5                   jsdiv  2-rlls-soft  0.034097  0.001606
# 62     0.5                   jsdiv         3-em  0.019194  0.000785
# 63     0.5                   jsdiv       wen15B  0.019191  0.000785
# 64     0.5         mseweights_even  1-bbse-soft  0.002831  0.000220
# 65     0.5         mseweights_even  2-rlls-soft  0.002833  0.000219
# 66     0.5         mseweights_even         3-em  0.001254  0.000165
# 67     0.5         mseweights_even       wen15B  0.001256  0.000164
# 68     0.5  mseweights_testsetprop  1-bbse-soft  0.004430  0.000652
# 69     0.5  mseweights_testsetprop  2-rlls-soft  0.004430  0.000647
# 70     0.5  mseweights_testsetprop         3-em  0.002027  0.000544
# 71     0.5  mseweights_testsetprop       wen15B  0.002043  0.000543
# 72     0.8             acc_adapted  1-bbse-soft  0.932000  0.001267
# 73     0.8             acc_adapted  2-rlls-soft  0.932000  0.001267
# 74     0.8             acc_adapted         3-em  0.932500  0.001263
# 75     0.8             acc_adapted       wen15B  0.932500  0.001263
# 76     0.8                acc_base  1-bbse-soft  0.916000  0.001359
# 77     0.8                acc_base  2-rlls-soft  0.916000  0.001359
# 78     0.8                acc_base         3-em  0.916000  0.001359
# 79     0.8                acc_base       wen15B  0.916000  0.001359
# 80     0.8               delta_acc  1-bbse-soft  0.014750  0.001012
# 81     0.8               delta_acc  2-rlls-soft  0.014750  0.001011
# 82     0.8               delta_acc         3-em  0.015250  0.001038
# 83     0.8               delta_acc       wen15B  0.015250  0.001039
# 84     0.8                   jsdiv  1-bbse-soft  0.026352  0.001211
# 85     0.8                   jsdiv  2-rlls-soft  0.026369  0.001216
# 86     0.8                   jsdiv         3-em  0.018236  0.000650
# 87     0.8                   jsdiv       wen15B  0.018267  0.000647
# 88     0.8         mseweights_even  1-bbse-soft  0.001903  0.000202
# 89     0.8         mseweights_even  2-rlls-soft  0.001903  0.000202
# 90     0.8         mseweights_even         3-em  0.001458  0.000125
# 91     0.8         mseweights_even       wen15B  0.001460  0.000125
# 92     0.8  mseweights_testsetprop  1-bbse-soft  0.002751  0.000607
# 93     0.8  mseweights_testsetprop  2-rlls-soft  0.002757  0.000607
# 94     0.8  mseweights_testsetprop         3-em  0.002096  0.000268
# 95     0.8  mseweights_testsetprop       wen15B  0.002067  0.000269
# 96     1.0             acc_adapted  1-bbse-soft  0.932000  0.001200
# 97     1.0             acc_adapted  2-rlls-soft  0.932000  0.001201
# 98     1.0             acc_adapted         3-em  0.932000  0.001207
# 99     1.0             acc_adapted       wen15B  0.932000  0.001208
# 100    1.0                acc_base  1-bbse-soft  0.916250  0.001401
# 101    1.0                acc_base  2-rlls-soft  0.916250  0.001401
# 102    1.0                acc_base         3-em  0.916250  0.001401
# 103    1.0                acc_base       wen15B  0.916250  0.001401
# 104    1.0               delta_acc  1-bbse-soft  0.013250  0.000895
# 105    1.0               delta_acc  2-rlls-soft  0.013250  0.000897
# 106    1.0               delta_acc         3-em  0.013500  0.000914
# 107    1.0               delta_acc       wen15B  0.013500  0.000913
# 108    1.0                   jsdiv  1-bbse-soft  0.022756  0.000969
# 109    1.0                   jsdiv  2-rlls-soft  0.022756  0.000969
# 110    1.0                   jsdiv         3-em  0.016908  0.000594
# 111    1.0                   jsdiv       wen15B  0.016934  0.000595
# 112    1.0         mseweights_even  1-bbse-soft  0.002279  0.000165
# 113    1.0         mseweights_even  2-rlls-soft  0.002261  0.000165
# 114    1.0         mseweights_even         3-em  0.001647  0.000118
# 115    1.0         mseweights_even       wen15B  0.001645  0.000118
# 116    1.0  mseweights_testsetprop  1-bbse-soft  0.003034  0.000471
# 117    1.0  mseweights_testsetprop  2-rlls-soft  0.003002  0.000469
# 118    1.0  mseweights_testsetprop         3-em  0.002487  0.000262
# 119    1.0  mseweights_testsetprop       wen15B  0.002507  0.000262
# 120   10.0             acc_adapted  1-bbse-soft  0.917000  0.000666
# 121   10.0             acc_adapted  2-rlls-soft  0.917000  0.000666
# 122   10.0             acc_adapted         3-em  0.917250  0.000673
# 123   10.0             acc_adapted       wen15B  0.917250  0.000672
# 124   10.0                acc_base  1-bbse-soft  0.916500  0.000639
# 125   10.0                acc_base  2-rlls-soft  0.916500  0.000639
# 126   10.0                acc_base         3-em  0.916500  0.000639
# 127   10.0                acc_base       wen15B  0.916500  0.000639
# 128   10.0               delta_acc  1-bbse-soft  0.000500  0.000340
# 129   10.0               delta_acc  2-rlls-soft  0.000500  0.000340
# 130   10.0               delta_acc         3-em  0.000000  0.000354
# 131   10.0               delta_acc       wen15B  0.000000  0.000354
# 132   10.0                   jsdiv  1-bbse-soft  0.014149  0.000361
# 133   10.0                   jsdiv  2-rlls-soft  0.014149  0.000361
# 134   10.0                   jsdiv         3-em  0.014094  0.000375
# 135   10.0                   jsdiv       wen15B  0.014101  0.000374
# 136   10.0         mseweights_even  1-bbse-soft  0.001679  0.000103
# 137   10.0         mseweights_even  2-rlls-soft  0.001679  0.000103
# 138   10.0         mseweights_even         3-em  0.001570  0.000112
# 139   10.0         mseweights_even       wen15B  0.001564  0.000112
# 140   10.0  mseweights_testsetprop  1-bbse-soft  0.001691  0.000123
# 141   10.0  mseweights_testsetprop  2-rlls-soft  0.001691  0.000123
# 142   10.0  mseweights_testsetprop         3-em  0.001705  0.000133
# 143   10.0  mseweights_testsetprop       wen15B  0.001714  0.000132

# %%
alpha_seq = results["alpha"].unique()
print(alpha_seq)
# Out:
# [ 0.1  0.2  0.5  0.8  1.  10. ]

# %%
table_seq = []
for alpha in alpha_seq[0:3]:
    tmp = results.loc[results["alpha"] == alpha]
    a1 = tmp[tmp["measure"] == "mseweights_even"][["mean", "std"]].values.reshape(-1, 1)
    a2 = tmp[tmp["measure"] == "mseweights_testsetprop"][["mean", "std"]].values.reshape(-1, 1)
    a3 = tmp[tmp["measure"] == "acc_adapted"][["mean", "std"]].values.reshape(-1, 1)
    table1 = np.concatenate([a1, a2, a3], axis=1)
    table_seq.append(table1)
table_seq = np.concatenate(table_seq, axis=1)
print(alpha_seq[0:3])
np.savetxt("savetable_mnist_dir1.txt", np.concatenate([table_seq], axis=1))
# Out:
# [0.1 0.2 0.5]

# %%
table_seq = []
for alpha in alpha_seq[3:6]:
    tmp = results.loc[results["alpha"] == alpha]
    a1 = tmp[tmp["measure"] == "mseweights_even"][["mean", "std"]].values.reshape(-1, 1)
    a2 = tmp[tmp["measure"] == "mseweights_testsetprop"][["mean", "std"]].values.reshape(-1, 1)
    a3 = tmp[tmp["measure"] == "acc_adapted"][["mean", "std"]].values.reshape(-1, 1)
    table1 = np.concatenate([a1, a2, a3], axis=1)
    table_seq.append(table1)
table_seq = np.concatenate(table_seq, axis=1)
print(alpha_seq[3:6])
np.savetxt("savetable_mnist_dir2.txt", np.concatenate([table_seq], axis=1))
# Out:
# [ 0.8  1.  10. ]
